# %%
# Imports
from rlcw.main import setup, enable_jupyter
from rlcw.orchestrator import Orchestrator

# %%
# Enables Jupyter Mode
enable_jupyter()

# %%
# %matplotlib inline
# run
seed = 42
env, agent, config = setup()
orchestrator = Orchestrator(env, agent, config, seed=seed)
orchestrator.run()
