# %%
# Imports
from rlcw.main import Orchestrator, setup

# %%
# %matplotlib inline

# run
seed = 42
env, agent, config = setup(from_jupyter=True)
orchestrator = Orchestrator(env, agent, config, seed=seed, from_jupyter=True)
orchestrator.run()
